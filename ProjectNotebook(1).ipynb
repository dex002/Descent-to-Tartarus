# %% [markdown]
# # Descent to Tartarus

# %% [markdown]
# This project is a turn-based dungeon crawler based off the classic roguelike dungeon crawler genre. The player selects a party of two heros from four unique classes each with their own unique skills. The party then enters endless dungeons, fighting randomly generated enemies that scale in difficulty with each floor. The game ends when both heroes are defeated, and the goal is simply to survive as many floors as possible.

# %% [markdown]
# ## Project Code
#
# Demonstrate how your project works here! (If it doesn't work from the notebook, describe what graders should do to execute your project.)

# %%
from module import pick_classes, dungeon, descend

#run the cell to start the game.

descend()
# Out:
# The breeze of the River Styx sends a chill down your spine...
# You look far across the land but see nothing but darkness...
# You look into the River Styx catching a glimpse of your reflection...
# Who do you see...?
#
# ——— Who do you see? ———
# 1. Aphros —— The Healer —— Excels in sustaining the team and lowering the enemy's attack.
# 2. Aspirda —— The Tank —— Fortifies the team by increasing defense while slowing the enemy.
# 3. Doros —— The Assassin —— High self-sustain with massive damage, lifesteal, and growing defense.
# 4. Lusios —— The Madman —— Excels in longer battles with chance-based skills and ramping damage.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from module import pick_classes, dungeon, descend
#       2
#       3 #run the cell to start the game.
#       4
# ----> 5 descend()
#
# File ~/module.py:726, in descend()
#     724 """Start the game from the beginning."""
#     725 intro()
# --> 726 party = pick_classes()
#     727 dungeon(party)
#
# File ~/module.py:269, in pick_classes()
#     265 print("3. Doros —— The Assassin —— High self-sustain " + \
#     266       "with massive damage, lifesteal, and growing defense.")
#     267 print("4. Lusios —— The Madman —— Excels in longer battles with " + \
#     268       "chance-based skills and ramping damage.")
# --> 269 choice1 = input("Pick your first hero (1-4): ")
#     270 time.sleep(1)
#     271 print("You look at the reflection next to you, who do you see?")
#
# File /opt/conda/lib/python3.12/site-packages/ipykernel/kernelbase.py:1260, in Kernel.raw_input(self, prompt)
#    1258     msg = "raw_input was called, but this frontend does not support input requests."
#    1259     raise StdinNotImplementedError(msg)
# -> 1260 return self._input_request(
#    1261     str(prompt),
#    1262     self._parent_ident["shell"],
#    1263     self.get_parent("shell"),
#    1264     password=False,
#    1265 )
#
# File /opt/conda/lib/python3.12/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Testing
#
# Run your tests. Sample code is provided below; you may need to edit this, depending upon how you've set up your tests.

# %%
# test it out
import unittest
import tests  # your tests.py file

unittest.main(tests.__name__, argv=[''], verbosity=2, exit=False)
# Out:
# test_calculate_damage (tests.TestCalculateDamage.test_calculate_damage) ... ok
# test_damage_minimum_zero (tests.TestCalculateDamage.test_damage_minimum_zero) ... ok
# test_alluring_kiss_heal (tests.TestHeroSkills.test_alluring_kiss_heal) ... ok
# test_bulwark_buff (tests.TestHeroSkills.test_bulwark_buff) ... ok
# test_deathbound_damage (tests.TestHeroSkills.test_deathbound_damage) ... ok
# test_sly_heal (tests.TestHeroSkills.test_sly_heal) ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.028s
#
# OK
# healer used Alluring Kiss!
# target healed 2 HP!
# buffer used Bulwark!
# buffer's defense increased by 3!
# attacker used Deathbound!
# target takes 7 damage!
# attacker used Sly!
# attacker stole 1 HP from target!

# %% [markdown]
# #### GenAI Statement
#
# My idea was a bit ambitious, and having three skills per character got a bit overwhelming. As such, GenAI helped me stay organized in case I missed a skill in the code. Additionally, GenAI helped with wording a lot of the descriptions, generating the stats for the enemies, giving ideas for the flavor text, and the power scaling as I was unsure how to balance the damage and the health. GenAI also helped with debugging errors throughout the development of the code.

# %% [markdown]
# #### Extra Credit (*optional*)
# I had minimal to no python background previously, though I have done a lot of work with R which gave me a bit of transferrable skills and so I did not feel like I was fully lost, but R does not use functions or classes so that was new for me. For my project, the first main challenge was using a lot of classes and constantly needing to call them again and again thoughout the code. Classes was probably the hardest thing for me to understand but it felt very neccessary to use for a game like this. Additionally, I used recursion a lot, which is something I don't think was covered much in this course. Recursion is when a function calls on itself, and I used this for this project because this project has a lot of inputs, so if the player picked a wrong input, it would call itself and prompt the player to re-pick something. I also used import time which is a new module that I used to make the game more atmospheric and makes the text easier to read and follow.
